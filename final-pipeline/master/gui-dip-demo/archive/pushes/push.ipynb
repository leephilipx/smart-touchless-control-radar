# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

sample = np.load('pushes-003.npz')['sample']
print(sample.shape)
norm_sample = np.abs(sample).T / np.max(np.abs(sample))
plt.imshow(norm_sample, aspect='auto', origin='lower', vmin=0, cmap='jet');
# Out:
# (64, 827)
